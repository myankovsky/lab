# %% [markdown]
# ## Лабораторная работа №4
# ### СПЕКТРОСКОПИЯ КОМБИНАЦИОННОГО РАССЕЯНИЯ СВЕТА ЖИДКИХ И ТВЕРДЫХ ВЕЩЕСТВ
#
# ### Цель:
# Изучить прибор ДФС-52 и порядок работы на нем. Рассмотреть спектр КР бензола С6Н6. Записать спектр КР бензола и оценить степень деполяризации линий КР. Сравнить экспериментальные данные с теоретически рассчитанными. Сформулировать правило альтернативного запрета в колебательных спектрах и проверить его на примере молекулы бензола.
#
#
# #### Выполнили: Смоляков Адам и Янковский Матвей

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt


# %matplotlib inline

# %%
data = pd.read_csv('спектр_1.csv', delimiter=';')
X = data['I']
Y = data['v']

plt.figure(figsize=(16, 10), dpi= 100, facecolor='w')
plt.plot(X, Y)

# Decorations
plt.gca().set(xlabel='Обратные см', ylabel='Интенсивность')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('спектр раствора бензола', fontsize=20)

plt.vlines(611, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(850, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(995, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(1180, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(1590, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')

# %%
spectr_2 = pd.read_csv('спектр_2.csv', delimiter=';')
X1 = spectr_2['I']
Y1 = spectr_2['v']

plt.figure(figsize=(16, 10), dpi= 100, facecolor='w')
plt.plot(X1, Y1)

plt.vlines(3092, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(3036, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(3070, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(1477, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(1036, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(1173, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(671, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(849, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(1813, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(1960, np.min(Y1), np.max(Y1), color = 'r', linewidth = 0.5, linestyle = '--')

# %% [markdown]
# Сравнение табличных и экспериментальных значений:

# %%
data = pd.read_csv('data.csv', sep=';').dropna()
data
# Out:
#   Номер колебания Unnamed: 1 Табличные значения Unnamed: 3  \
# 1             ṽ20         ṽ6               3080        607
# 4             ṽ19        ṽ10               1485        850
# 5             ṽ18         ṽ1               1037        992
# 6              ṽ9         ṽ9               1178       1178
# 7             ṽ10         ṽ8                849       1596
#
#   Экспериментальные значения Unnamed: 5
# 1                       3090        611
# 4                       1477        850
# 5                       1036        995
# 6                       1173       1180
# 7                    851,591       1590

# %% [markdown]
# Молекула бензола характеризуется 30-ю нормальными колебаниями (3N-6), распределенными между 12-ю типами симметрии. Все 30 колебаний молекулы бензола распределяются между следующими типами симметрии
#
# $ Г_(D_6h )=2A_1g+A_2g+〖2B〗_2g+E_1g+4E_2g+A_2u+2B_1u+2B_2u+3E_1u+2E_2u $

# %% [markdown]
# ### Вывод
# В данной работе мы изучили инфракрасный спектр и  спектр комбинационное рассеяние бензола. Сравнили экспериментальные данные с теоретическими. В ходе которых выяснилось, что они не согласуются с расчетными.
