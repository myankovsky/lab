# %% [markdown]
# # Лабораторная работа № 1
# ## "КОЛЕБАТЕЛЬНО-ВРАЩАТЕЛЬНЫЕ СПЕКТРЫ ДВУХАТОМНЫХ МОЛЕКУЛ"
#
#
# Цель:
# Экспериментальное исследование колебательно-вращательного спектра поглощения молекулы CO. Расчет по полученным данным вращательной постоянной, волновых чисел колебательно-вращательных полос, значения момента инерции молекулы, величины межатомного расстояния
#
#     Выполнили: Смоляков Адам, Янковский Матвей

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(filename ="1.png", width=400, height=400)

# %% [markdown]
# Рис.2 Оптический путь
#     А – светоделитель;
#     В – диск оптического фильтра;
#     С – диск апертуры;
# D – детектор;
# E – окно кюветного отсека;
# F – Источник света.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
data = pd.read_csv('Spectr_CO.csv', delimiter=';')
X = data['I']
Y = data['v']

plt.figure(figsize=(16, 10), dpi= 100, facecolor='w')
plt.plot(X, Y)

# Decorations
plt.gca().set(xlabel='Обратные см', ylabel='Интенсивность')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Колебательно-вращательный спектр двухатомной молекула СО в области 2050–2250 см^(-1) ', fontsize=20)

plt.vlines(2162.2, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2158.5, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2154.8, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2151.1, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2147.3, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')

plt.vlines(2139.6, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2135.7, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2131.7, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2127.8, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.vlines(2123.9, np.min(Y), np.max(Y), color = 'r', linewidth = 0.5, linestyle = '--')
plt.show()

# %%
print("Значение вращательных квантовых чисел J' и J'' для полос P- и R- ветвей спектра")
P = pd.read_csv('P-curve.csv', sep=';')
P
# Out:
# Значение вращательных квантовых чисел J' и J'' для полос P- и R- ветвей спектра
#    P-curve     cm^1  J'  J"
# 0        1  2147.73   0   1
# 1        2  2151.10   1   2
# 2        3  2154.80   2   3
# 3        4  2158.50   3   4
# 4        5  2162.20   4   5

# %%
R = pd.read_csv('R-curve.csv', sep=';')
R
# Out:
#    R-curve   cm^-1  J'  J"
# 0        1  2139.6   1   0
# 1        2  2135.7   2   1
# 2        3  2131.7   3   2
# 3        4  2127.8   4   3
# 4        5  2123.9   5   4

# %%
nu_1 = 2147.3 - (2139.6) 
m_1 = 1
B_1 = nu_1/ (4*m_1)

nu_2 = 2151.1 - 2135.7
m_2 = 2
B_2 = nu_2/ (4*m_2)

nu_3 = 2154.8 - 2131.7
m_3 = 3
B_3 = nu_3/ (4*m_3)

nu_4 = 2158.5 - 2127.8
m_4 = 4
B_4 = nu_4/ (4*m_4)

nu_5 = 2162.2 - 2123.9
m_5 = 5
B_5 = nu_5/ (4*m_5)

print('значение вращательной постоянной молекулы СО¶')
B_1, B_2, B_3, B_4, B_5
# Out:
# значение вращательной постоянной молекулы СО¶
# (1.9250000000000682,
#  1.9250000000000114,
#  1.9250000000000302,
#  1.9187499999999886,
#  1.9149999999999863)

# %%
h = 1.056 * 10**(-34)
I_1 = h**2 / (2*B_1)
I_2 = h**2 / (2*B_2)
I_3 = h**2 / (2*B_3)
I_4 = h**2 / (2*B_4)
I_5 = h**2 / (2*B_5)

print(' значение момента инерции I [кг * m^2] молекулы СО.')
I = (2.7992 * 10**(-46)) / (B_1)
I
# Out:
#  значение момента инерции I [кг * m^2] молекулы СО.
# 1.4541298701298187e-46

# %%
m_o = 5.312 * 10**(-26)
m_c = 1.998 * 10**(-26)
r = np.sqrt(((m_c + m_o)*I)  / ((m_c * m_o)))
print('величина межатомного расстояния rCO = {} m'.format(r))
# Out:
# величина межатомного расстояния rCO = 1.000768232786137e-10 m

# %% [markdown]
# Вывод:
# В данной работе был изучен колебательно-вращательный спектр двухатомной молекула СО. Рассчитаны по полученным данным: вращательная постоянная, волновые числа колебательно-вращательных полос, значение момента инерции молекулы CO, величина межатомного расстояния. Полученные значения оказались близки к табличным, где r_e=0,1131 нм, B_e= 1,9212〖 см〗^(-1).
